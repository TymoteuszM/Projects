# %%
import pandas as pd 
df=pd.read_csv("healthcare-dataset-stroke-data.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
#Brakuje niektórych wartości parametru BMI, zostanie uzupełnione na podstawie k-najbliższych elementow
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
#Wykorzystam dummy encoding dla male/female/other
print(df["gender"].unique())
print(df["ever_married"].unique())
print(df["work_type"].unique())
print(df["Residence_type"].unique())
print(df["smoking_status"].unique())
# Out:
# ['Male' 'Female' 'Other']
# ['Yes' 'No']
# ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# ['Urban' 'Rural']
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']

# %%
#Liczba kobiet/męzczyzn/innych
df["gender"].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
#getting dummies for gender,ever_married,work_type,residence_type,smoking_status
df1 = pd.get_dummies(df["gender"], drop_first = True)
df2 = pd.get_dummies(df["ever_married"], drop_first = True)
df3 = pd.get_dummies(df["work_type"], drop_first = True)
df4 = pd.get_dummies(df["Residence_type"], drop_first = True)
df5 = pd.get_dummies(df["smoking_status"], drop_first = True)

# %%
df=df.drop(["gender","ever_married","work_type","Residence_type","smoking_status"],axis=1)

# %%
df = pd.concat([df, df1,df2,df3,df4,df5], axis = 1)

# %%
Y=df["stroke"]
X=df.drop(["stroke","id"],axis=1)

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors = 5)
X= pd.DataFrame(imputer.fit_transform(X), columns = X.columns)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
X_train.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'Male', 'Other', 'Yes', 'Never_worked', 'Private', 'Self-employed',
#        'children', 'Urban', 'formerly smoked', 'never smoked', 'smokes'],
#       dtype='object')

# %%
y_test
# Out:
# 42      1
# 380     0
# 3524    0
# 352     0
# 4927    0
#        ..
# 929     0
# 2629    0
# 663     0
# 2303    0
# 3122    0
# Name: stroke, Length: 1533, dtype: int64

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import cross_val_score

# %%
model = keras.Sequential(
    [
        layers.Dense(20,input_dim=16, activation="relu"),
        layers.Dense(12, activation="relu"),
        layers.Dense(8, activation="relu"),
        layers.Dense(1, activation="sigmoid"),
    ])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['AUC',])

# %%
model.fit(X_train, y_train, epochs=250, batch_size=10)
# Out:
# Epoch 1/250
# 358/358 [==============================] - 1s 1ms/step - loss: 0.2368 - auc: 0.5782
# Epoch 2/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1988 - auc: 0.6805
# Epoch 3/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1956 - auc: 0.6919
# Epoch 4/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1852 - auc: 0.7304
# Epoch 5/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1811 - auc: 0.7411
# Epoch 6/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1808 - auc: 0.7542
# Epoch 7/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1771 - auc: 0.7621
# Epoch 8/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1737 - auc: 0.7692
# Epoch 9/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1737 - auc: 0.7703
# Epoch 10/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1733 - auc: 0.7742
# Epoch 11/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1766 - auc: 0.7637
# Epoch 12/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1693 - auc: 0.7873
# Epoch 13/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1691 - auc: 0.7947
# Epoch 14/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1672 - auc: 0.7933
# Epoch 15/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1682 - auc: 0.7993
# Epoch 16/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1706 - auc: 0.7917
# Epoch 17/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1662 - auc: 0.7956
# Epoch 18/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1647 - auc: 0.8009
# Epoch 19/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1625 - auc: 0.8110
# Epoch 20/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1651 - auc: 0.8051
# Epoch 21/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1635 - auc: 0.8076
# Epoch 22/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1648 - auc: 0.8028
# Epoch 23/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1604 - auc: 0.8188
# Epoch 24/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1627 - auc: 0.8082
# Epoch 25/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1640 - auc: 0.8074
# Epoch 26/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1660 - auc: 0.8001
# Epoch 27/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1630 - auc: 0.8116
# Epoch 28/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1638 - auc: 0.8065
# Epoch 29/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1626 - auc: 0.8097
# Epoch 30/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1580 - auc: 0.8257
# Epoch 31/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1595 - auc: 0.8222
# Epoch 32/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1624 - auc: 0.8125
# Epoch 33/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1633 - auc: 0.8053
# Epoch 34/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1671 - auc: 0.7938
# Epoch 35/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1661 - auc: 0.8124
# Epoch 36/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1598 - auc: 0.8248
# Epoch 37/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1600 - auc: 0.8257
# Epoch 38/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1584 - auc: 0.8279
# Epoch 39/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1598 - auc: 0.8215
# Epoch 40/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1565 - auc: 0.8345
# Epoch 41/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1589 - auc: 0.8287
# Epoch 42/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1586 - auc: 0.8243
# Epoch 43/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1575 - auc: 0.8328
# Epoch 44/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1570 - auc: 0.8334
# Epoch 45/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1596 - auc: 0.8214
# Epoch 46/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1580 - auc: 0.8317
# Epoch 47/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1579 - auc: 0.8330
# Epoch 48/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1559 - auc: 0.8422
# Epoch 49/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1554 - auc: 0.8384
# Epoch 50/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1568 - auc: 0.8311
# Epoch 51/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1563 - auc: 0.8334
# Epoch 52/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1573 - auc: 0.8288
# Epoch 53/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1566 - auc: 0.8367
# Epoch 54/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1558 - auc: 0.8369
# Epoch 55/250
# 358/358 [==============================] - 1s 2ms/step - loss: 0.1548 - auc: 0.8388
# Epoch 56/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1572 - auc: 0.8309
# Epoch 57/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1546 - auc: 0.8400
# Epoch 58/250
# 358/358 [==============================] - 0s 983us/step - loss: 0.1555 - auc: 0.8403
# Epoch 59/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1552 - auc: 0.8404
# Epoch 60/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1544 - auc: 0.8435
# Epoch 61/250
# 358/358 [==============================] - 0s 997us/step - loss: 0.1561 - auc: 0.8390
# Epoch 62/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1543 - auc: 0.8438
# Epoch 63/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1556 - auc: 0.8382
# Epoch 64/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1540 - auc: 0.8452
# Epoch 65/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1545 - auc: 0.8426
# Epoch 66/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1545 - auc: 0.8437
# Epoch 67/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1582 - auc: 0.8289
# Epoch 68/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1555 - auc: 0.8396
# Epoch 69/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1531 - auc: 0.8434
# Epoch 70/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1546 - auc: 0.8424
# Epoch 71/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1533 - auc: 0.8483
# Epoch 72/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1559 - auc: 0.8417
# Epoch 73/250
# 358/358 [==============================] - 1s 2ms/step - loss: 0.1547 - auc: 0.8393
# Epoch 74/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1519 - auc: 0.8500
# Epoch 75/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1542 - auc: 0.8403
# Epoch 76/250
# 358/358 [==============================] - 1s 1ms/step - loss: 0.1516 - auc: 0.8481
# Epoch 77/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1514 - auc: 0.8537
# Epoch 78/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1527 - auc: 0.8492
# Epoch 79/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1521 - auc: 0.8511
# Epoch 80/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1534 - auc: 0.8468
# Epoch 81/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1522 - auc: 0.8466
# Epoch 82/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1523 - auc: 0.8502
# Epoch 83/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1535 - auc: 0.8455
# Epoch 84/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1524 - auc: 0.8489
# Epoch 85/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1495 - auc: 0.8605
# Epoch 86/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1512 - auc: 0.8509
# Epoch 87/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1519 - auc: 0.8513
# Epoch 88/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1523 - auc: 0.8520
# Epoch 89/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1532 - auc: 0.8466
# Epoch 90/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1497 - auc: 0.8574
# Epoch 91/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1503 - auc: 0.8535
# Epoch 92/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1526 - auc: 0.8475
# Epoch 93/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1507 - auc: 0.8525
# Epoch 94/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1499 - auc: 0.8549
# Epoch 95/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1532 - auc: 0.8471
# Epoch 96/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1510 - auc: 0.8508
# Epoch 97/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1518 - auc: 0.8522
# Epoch 98/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1519 - auc: 0.8511
# Epoch 99/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1487 - auc: 0.8600
# Epoch 100/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1501 - auc: 0.8519
# Epoch 101/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1536 - auc: 0.8456
# Epoch 102/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1517 - auc: 0.8522
# Epoch 103/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1501 - auc: 0.8571
# Epoch 104/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1505 - auc: 0.8522
# Epoch 105/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1530 - auc: 0.8461
# Epoch 106/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1491 - auc: 0.8583
# Epoch 107/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1519 - auc: 0.8517
# Epoch 108/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1495 - auc: 0.8573
# Epoch 109/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1491 - auc: 0.8610
# Epoch 110/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1471 - auc: 0.8630
# Epoch 111/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1521 - auc: 0.8571
# Epoch 112/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1490 - auc: 0.8605
# Epoch 113/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1475 - auc: 0.8623
# Epoch 114/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1481 - auc: 0.8617
# Epoch 115/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1475 - auc: 0.8637
# Epoch 116/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1488 - auc: 0.8620
# Epoch 117/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1487 - auc: 0.8570
# Epoch 118/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1498 - auc: 0.8589
# Epoch 119/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1504 - auc: 0.8543
# Epoch 120/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1493 - auc: 0.8571
# Epoch 121/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1461 - auc: 0.8663
# Epoch 122/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1502 - auc: 0.8568
# Epoch 123/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1488 - auc: 0.8637
# Epoch 124/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1488 - auc: 0.8598
# Epoch 125/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1477 - auc: 0.8638
# Epoch 126/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1490 - auc: 0.8586
# Epoch 127/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1486 - auc: 0.8608
# Epoch 128/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1477 - auc: 0.8632
# Epoch 129/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1488 - auc: 0.8598
# Epoch 130/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1460 - auc: 0.8671
# Epoch 131/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1479 - auc: 0.8613
# Epoch 132/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1480 - auc: 0.8638
# Epoch 133/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1486 - auc: 0.8634
# Epoch 134/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1461 - auc: 0.8667
# Epoch 135/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1465 - auc: 0.8644
# Epoch 136/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1470 - auc: 0.8658
# Epoch 137/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1487 - auc: 0.8580
# Epoch 138/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1484 - auc: 0.8585
# Epoch 139/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1460 - auc: 0.8674
# Epoch 140/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1474 - auc: 0.8629
# Epoch 141/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1474 - auc: 0.8633
# Epoch 142/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1461 - auc: 0.8697
# Epoch 143/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1466 - auc: 0.8680
# Epoch 144/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1476 - auc: 0.8619
# Epoch 145/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1445 - auc: 0.8721
# Epoch 146/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1444 - auc: 0.8736
# Epoch 147/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1477 - auc: 0.8639
# Epoch 148/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1460 - auc: 0.8662
# Epoch 149/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1458 - auc: 0.8667
# Epoch 150/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1470 - auc: 0.8630
# Epoch 151/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1457 - auc: 0.8692
# Epoch 152/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1467 - auc: 0.8653
# Epoch 153/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1471 - auc: 0.8657
# Epoch 154/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1463 - auc: 0.8716
# Epoch 155/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1450 - auc: 0.8711
# Epoch 156/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1458 - auc: 0.8704
# Epoch 157/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1457 - auc: 0.8679
# Epoch 158/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1460 - auc: 0.8685
# Epoch 159/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1476 - auc: 0.8655
# Epoch 160/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1446 - auc: 0.8725
# Epoch 161/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1498 - auc: 0.8636
# Epoch 162/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1461 - auc: 0.8691
# Epoch 163/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1455 - auc: 0.8671
# Epoch 164/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1455 - auc: 0.8691
# Epoch 165/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1437 - auc: 0.8743
# Epoch 166/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1445 - auc: 0.8691
# Epoch 167/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1449 - auc: 0.8725
# Epoch 168/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1452 - auc: 0.8687
# Epoch 169/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1462 - auc: 0.8657
# Epoch 170/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1452 - auc: 0.8711
# Epoch 171/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1459 - auc: 0.8703
# Epoch 172/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1469 - auc: 0.8645
# Epoch 173/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1442 - auc: 0.8730
# Epoch 174/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1453 - auc: 0.8690
# Epoch 175/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1455 - auc: 0.8675
# Epoch 176/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1447 - auc: 0.8708
# Epoch 177/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1439 - auc: 0.8734
# Epoch 178/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1437 - auc: 0.8764
# Epoch 179/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1449 - auc: 0.8718
# Epoch 180/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1451 - auc: 0.8696
# Epoch 181/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1441 - auc: 0.8735
# Epoch 182/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1441 - auc: 0.8728
# Epoch 183/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1434 - auc: 0.8776
# Epoch 184/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1450 - auc: 0.8706
# Epoch 185/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1439 - auc: 0.8744
# Epoch 186/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1447 - auc: 0.8734
# Epoch 187/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1443 - auc: 0.8722
# Epoch 188/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1436 - auc: 0.8741
# Epoch 189/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1456 - auc: 0.8674
# Epoch 190/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1428 - auc: 0.8771
# Epoch 191/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1452 - auc: 0.8706
# Epoch 192/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1467 - auc: 0.8720
# Epoch 193/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1437 - auc: 0.8745
# Epoch 194/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1453 - auc: 0.8707
# Epoch 195/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1435 - auc: 0.8759
# Epoch 196/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1430 - auc: 0.8790
# Epoch 197/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1439 - auc: 0.8752
# Epoch 198/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1455 - auc: 0.8693
# Epoch 199/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1415 - auc: 0.8811
# Epoch 200/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1441 - auc: 0.8737
# Epoch 201/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1431 - auc: 0.8770
# Epoch 202/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1443 - auc: 0.8727
# Epoch 203/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1439 - auc: 0.8751
# Epoch 204/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1423 - auc: 0.8772
# Epoch 205/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1426 - auc: 0.8777
# Epoch 206/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1447 - auc: 0.8722
# Epoch 207/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1422 - auc: 0.8777
# Epoch 208/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1436 - auc: 0.8731
# Epoch 209/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1441 - auc: 0.8721
# Epoch 210/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1432 - auc: 0.8768
# Epoch 211/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1438 - auc: 0.8733
# Epoch 212/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1460 - auc: 0.8689
# Epoch 213/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1425 - auc: 0.8788
# Epoch 214/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1427 - auc: 0.8802
# Epoch 215/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1460 - auc: 0.8708
# Epoch 216/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1451 - auc: 0.8699
# Epoch 217/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1415 - auc: 0.8816
# Epoch 218/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1419 - auc: 0.8785
# Epoch 219/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1414 - auc: 0.8805
# Epoch 220/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1427 - auc: 0.8770
# Epoch 221/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1441 - auc: 0.8745
# Epoch 222/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1445 - auc: 0.8746
# Epoch 223/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1434 - auc: 0.8748
# Epoch 224/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1431 - auc: 0.8771
# Epoch 225/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1426 - auc: 0.8770
# Epoch 226/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1403 - auc: 0.8837
# Epoch 227/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1434 - auc: 0.8760
# Epoch 228/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1447 - auc: 0.8733
# Epoch 229/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1414 - auc: 0.8804
# Epoch 230/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1428 - auc: 0.8769
# Epoch 231/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1414 - auc: 0.8796
# Epoch 232/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1417 - auc: 0.8796
# Epoch 233/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1420 - auc: 0.8781
# Epoch 234/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1407 - auc: 0.8817
# Epoch 235/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1406 - auc: 0.8829
# Epoch 236/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1412 - auc: 0.8802
# Epoch 237/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1412 - auc: 0.8813
# Epoch 238/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1414 - auc: 0.8811
# Epoch 239/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1393 - auc: 0.8872
# Epoch 240/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1412 - auc: 0.8800
# Epoch 241/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1442 - auc: 0.8721
# Epoch 242/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1402 - auc: 0.8841
# Epoch 243/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1476 - auc: 0.8723
# Epoch 244/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1390 - auc: 0.8881
# Epoch 245/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1417 - auc: 0.8787
# Epoch 246/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1398 - auc: 0.8855
# Epoch 247/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1406 - auc: 0.8816
# Epoch 248/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1414 - auc: 0.8791
# Epoch 249/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1386 - auc: 0.8867
# Epoch 250/250
# 358/358 [==============================] - 0s 1ms/step - loss: 0.1411 - auc: 0.8852

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                340
#
#  dense_1 (Dense)             (None, 12)                252
#
#  dense_2 (Dense)             (None, 8)                 104
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 705
# Trainable params: 705
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_predict = model.predict(X_test)

# %%
y_predict=(y_predict>0.2)

# %%
y_predict
# Out:
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
y_predict=y_predict.astype(int)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_predict))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7380\2438890624.py in <module>
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print(accuracy_score(y_test,y_predict))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_test, y_predict)
print(cm)
from sklearn.metrics import ConfusionMatrixDisplay


cm_display = ConfusionMatrixDisplay(cm).plot()
# Out:
# [[1423   34]
#  [  69    7]]

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay

fpr, tpr, _ = roc_curve(y_test, y_predict)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr).plot()

# %%
from  sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_predict)
# Out:
# 0.7595094462305386
